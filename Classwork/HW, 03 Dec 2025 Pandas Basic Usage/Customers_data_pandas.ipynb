# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\DELL\Downloads\customers\customers.csv")
print(df.head())
print("\nData at index 2:")
print(df.loc[2])
# Out:
#    Index      Customer Id First Name Last Name                  Company  \
# 0      1  4962fdbE6Bfee6D        Pam    Sparks             Patel-Deleon
# 1      2  9b12Ae76fdBc9bE       Gina     Rocha  Acosta, Paul and Barber
# 2      3  39edFd2F60C85BC    Kristie     Greer                Ochoa PLC
# 3      4  Fa42AE6a9aD39cE     Arthur    Fields               Moyer-Wang
# 4      5  F5702Edae925F1D   Michelle   Blevins            Shah and Sons
#
#                City                                            Country  \
# 0        Blakemouth  British Indian Ocean Territory (Chagos Archipe...
# 1  East Lynnchester                                         Costa Rica
# 2       West Pamela                                            Ecuador
# 3      East Belinda                                        Afghanistan
# 4        West Jared                                   Marshall Islands
#
#                   Phone 1                Phone 2  \
# 0        267-243-9490x035       480-078-0535x889
# ...
